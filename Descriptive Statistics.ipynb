# %%
import trackml
import pandas as pd
import matplotlib as plt
import seaborn as sns
import scipy

# %%
from trackml.dataset import load_event

# %%
# %ls
# Out:
# Descriptive Statistics.ipynb  trackml-library/
# requirements.txt              train_100_events/
# test/                         visualizations.ipynb

# %%
hits, cells, particles, truth =load_event('/Users/donovanadams/Desktop/GitHub/trackml/train_100_events/event000001000')

# %% [markdown]
# ### Hit data and associated features

# %%
hits.head()
# Out:
#    hit_id          x         y       z  volume_id  layer_id  module_id
# 0       1 -64.409897 -7.163700 -1502.5          7         2          1
# 1       2 -55.336102  0.635342 -1502.5          7         2          1
# 2       3 -83.830498 -1.143010 -1502.5          7         2          1
# 3       4 -96.109100 -8.241030 -1502.5          7         2          1
# 4       5 -62.673599 -9.371200 -1502.5          7         2          1

# %%
hits['volume_id'].describe()
# Out:
# count    120939.000000
# mean         10.921564
# std           3.365705
# min           7.000000
# 25%           8.000000
# 50%           9.000000
# 75%          13.000000
# max          18.000000
# Name: volume_id, dtype: float64

# %%
hits['volume_id'].value_counts()
# Out:
# 8     29172
# 13    25990
# 9     17186
# 7     16873
# 17    10356
# 12     7931
# 14     7585
# 18     2931
# 16     2915
# Name: volume_id, dtype: int64

# %%
hits['layer_id'].describe()
# Out:
# count    120939.000000
# mean          5.918389
# std           3.407428
# min           2.000000
# 25%           4.000000
# 50%           6.000000
# 75%           8.000000
# max          14.000000
# Name: layer_id, dtype: float64

# %%
hits['layer_id'].value_counts()
# Out:
# 2     29453
# 4     27768
# 6     21591
# 8     20286
# 10     8648
# 12     8615
# 14     4578
# Name: layer_id, dtype: int64

# %%
hits['module_id'].describe()
# Out:
# count    120939.000000
# mean        371.969117
# std         529.032206
# min           1.000000
# 25%          60.000000
# 50%         119.000000
# 75%         490.000000
# max        3192.000000
# Name: module_id, dtype: float64

# %%
hits['module_id'].value_counts().head()
# Out:
# 106    997
# 93     956
# 90     927
# 1      921
# 71     906
# Name: module_id, dtype: int64

# %% [markdown]
# ### Cells data and associated features

# %%
cells.head()
# Out:
#    hit_id  ch0  ch1     value
# 0       1  209  617  0.013832
# 1       1  210  617  0.079887
# 2       1  209  618  0.211723
# 3       2   68  446  0.334087
# 4       3   58  954  0.034005

# %%
cells['ch0'].describe()
# Out:
# count    664996.000000
# mean        211.529248
# std         156.399517
# min           0.000000
# 25%          97.000000
# 50%         191.000000
# 75%         287.000000
# max        1195.000000
# Name: ch0, dtype: float64

# %%
cells['ch0'].value_counts()
# Out:
# 102     2038
# 244     2034
# 314     2017
# 332     2016
# 178     2014
# 81      2011
# 145     2010
# 82      2010
# 240     2009
# 144     1984
# 95      1980
# 282     1979
# 77      1979
# 101     1975
# 155     1974
# 217     1971
# 170     1965
# 263     1957
# 166     1954
# 154     1947
# 191     1947
# 34      1946
# 274     1939
# 151     1938
# 192     1932
# 211     1930
# 177     1929
# 171     1927
# 35      1924
# 284     1923
#         ...
# 1107       3
# 1083       3
# 1161       3
# 1177       3
# 1160       3
# 1170       3
# 1172       3
# 1174       3
# 1179       2
# 1178       2
# 1158       2
# 1171       2
# 1173       2
# 1194       2
# 1193       2
# 1192       2
# 1191       2
# 1188       2
# 1175       2
# 1187       2
# 1176       2
# 1183       2
# 1190       1
# 1189       1
# 1195       1
# 1185       1
# 1184       1
# 1159       1
# 1181       1
# 1180       1
# Name: ch0, Length: 1194, dtype: int64

# %%
cells['ch1'].describe()
# Out:
# count    664996.000000
# mean        444.395715
# std         411.081790
# min           0.000000
# 25%          55.000000
# 50%         340.000000
# 75%         802.000000
# max        1279.000000
# Name: ch1, dtype: float64

# %%
cells['ch1'].value_counts()
# Out:
# 3       8230
# 5       8206
# 6       8158
# 9       8053
# 8       7933
# 7       7846
# 2       7800
# 1       7789
# 4       7767
# 0       7743
# 12      3077
# 10      2942
# 13      2913
# 11      2883
# 14      2734
# 66      2012
# 68      1971
# 77      1967
# 70      1953
# 40      1948
# 26      1934
# 56      1929
# 55      1929
# 23      1926
# 75      1925
# 51      1922
# 73      1916
# 39      1903
# 57      1901
# 46      1901
#         ...
# 1159     310
# 1078     309
# 1079     309
# 1137     309
# 1089     308
# 1139     308
# 1004     308
# 1272     308
# 1008     307
# 1136     307
# 1211     306
# 1273     306
# 1095     306
# 1126     306
# 1127     305
# 1096     305
# 1059     304
# 1094     303
# 1161     303
# 1162     303
# 1083     302
# 1003     299
# 692      295
# 1092     295
# 1274     277
# 1276     262
# 1275     262
# 1277     251
# 1278     217
# 1279     183
# Name: ch1, Length: 1280, dtype: int64

# %%
cells['value'].describe()
# Out:
# count    6.649960e+05
# mean     3.560307e-01
# std      4.322301e-01
# min      1.461840e-07
# 25%      5.364857e-02
# 50%      6.512935e-02
# 75%      1.000000e+00
# max      1.000000e+00
# Name: value, dtype: float64

# %%
cells['value'].value_counts()
# Out:
# 1.000000    204726
# 0.056807         9
# 0.057701         9
# 0.060897         8
# 0.057033         8
# 0.058495         8
# 0.058537         8
# 0.056100         8
# 0.058483         8
# 0.055852         8
# 0.054804         8
# 0.061673         8
# 0.059550         8
# 0.060098         8
# 0.059381         8
# 0.057314         8
# 0.059163         8
# 0.062073         8
# 0.058663         7
# 0.052779         7
# 0.055775         7
# 0.058561         7
# 0.057740         7
# 0.053889         7
# 0.058124         7
# 0.057052         7
# 0.058741         7
# 0.056558         7
# 0.057347         7
# 0.057005         7
#              ...
# 0.017331         1
# 0.069325         1
# 0.277298         1
# 0.069324         1
# 0.277296         1
# 0.069323         1
# 0.277293         1
# 0.069323         1
# 0.069323         1
# 0.069322         1
# 0.069322         1
# 0.004333         1
# 0.069321         1
# 0.069320         1
# 0.069317         1
# 0.017330         1
# ...

# %% [markdown]
# ## Particle data and associated features

# %%
particles.head()
# Out:
#         particle_id        vx        vy        vz         px         py  \
# 0  4503668346847232 -0.009288  0.009861 -0.077879  -0.055269   0.323272
# 1  4503737066323968 -0.009288  0.009861 -0.077879  -0.948125   0.470892
# 2  4503805785800704 -0.009288  0.009861 -0.077879  -0.886484   0.105749
# 3  4503874505277440 -0.009288  0.009861 -0.077879   0.257539  -0.676718
# 4  4503943224754176 -0.009288  0.009861 -0.077879  16.439400 -15.548900
#
#           pz  q  nhits
# 0  -0.203492 -1      8
# 1   2.010060  1     11
# 2   0.683881 -1      0
# 3   0.991616  1     12
# 4 -39.824902  1      3

# %%
particles['particle_id'].value_counts()
# Out:
# 851187338976432129    1
# 211675848275656704    1
# 914234916244291584    1
# 306251096869834753    1
# 734106118153830400    1
# 734102269863133184    1
# 166643219256311808    1
# 684549204944617472    1
# 639521798622298114    1
# 99079810277441536     1
# 801655508376227841    1
# 49540695412703232     1
# 18019552470237184     1
# 698058285856595970    1
# 112592258426994688    1
# 229690315504615424    1
# 873744094881382400    1
# 819655750656720896    1
# 355792891794165761    1
# 855684135375605761    1
# 598979918671380480    1
# 364801946457997312    1
# 495406679265918978    1
# 45041699990274048     1
# 968278111806296065    1
# 99080566191685632     1
# 153125617146003456    1
# 693556679077265408    1
# 139621003016798208    1
# 693558397064183808    1
#                      ..
# 49543238033342464     1
# 891712863658311680    1
# 954768481121730560    1
# 585470081861943296    1
# 819656369132011520    1
# 648522263351525376    1
# 180151063200923648    1
# ...

# %%
particles['q'].describe()
# Out:
# count    12263.000000
# mean         0.107233
# std          0.994274
# min         -1.000000
# 25%         -1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: q, dtype: float64

# %%
particles['q'].value_counts()
# Out:
#  1    6789
# -1    5474
# Name: q, dtype: int64

# %%
particles['nhits'].describe()
# Out:
# count    12263.000000
# mean         8.424121
# std          5.033464
# min          0.000000
# 25%          4.000000
# 50%         10.000000
# 75%         12.000000
# max         19.000000
# Name: nhits, dtype: float64

# %%
particles['nhits'].value_counts()
# Out:
# 0     1698
# 12    1679
# 11    1558
# 13    1347
# 10    1037
# 14     829
# 1      677
# 9      551
# 15     382
# 8      375
# 6      355
# 2      332
# 4      329
# 5      327
# 7      312
# 3      264
# 16     159
# 17      37
# 18      13
# 19       2
# Name: nhits, dtype: int64

# %% [markdown]
# ### Truth data and associated features

# %%
truth.head()
# Out:
#    hit_id         particle_id         tx        ty      tz            tpx  \
# 0       1                   0 -64.411598 -7.164120 -1502.5  250710.000000
# 1       2   22525763437723648 -55.338501  0.630805 -1502.5      -0.570605
# 2       3                   0 -83.828003 -1.145580 -1502.5  626295.000000
# 3       4  297237712845406208 -96.122902 -8.230360 -1502.5      -0.225235
# 4       5  418835796137607168 -62.659401 -9.375040 -1502.5      -0.281806
#
#              tpy           tpz    weight
# 0 -149908.000000 -956385.00000  0.000000
# 1       0.028390     -15.49220  0.000010
# 2 -169767.000000 -760877.00000  0.000000
# 3      -0.050968      -3.70232  0.000008
# 4      -0.023487      -6.57318  0.000009

# %%
truth['weight'].describe()
# Out:
# count    120939.000000
# mean          0.000008
# std           0.000008
# min           0.000000
# 25%           0.000004
# 50%           0.000007
# 75%           0.000011
# max           0.000165
# Name: weight, dtype: float64

# %%
truth['weight'].value_counts()
# Out:
# 0.000000    19767
# 0.000003     2716
# 0.000004     2553
# 0.000004     2334
# 0.000006     1830
# 0.000005     1358
# 0.000007     1358
# 0.000003     1329
# 0.000004     1232
# 0.000005     1227
# 0.000005      851
# 0.000006      851
# 0.000007      851
# 0.000005      851
# 0.000012      851
# 0.000007      851
# 0.000007      851
# 0.000011      851
# 0.000009      851
# 0.000010      819
# 0.000008      817
# 0.000003      804
# 0.000009      778
# 0.000014      778
# 0.000006      778
# 0.000008      778
# 0.000005      778
# 0.000008      778
# 0.000007      778
# 0.000011      778
#             ...
# 0.000050        1
# 0.000007        1
# 0.000009        1
# 0.000034        1
# 0.000021        1
# 0.000013        1
# 0.000018        1
# 0.000010        1
# 0.000006        1
# 0.000015        1
# 0.000015        1
# 0.000009        1
# 0.000005        1
# 0.000005        1
# 0.000018        1
# 0.000018        1
# 0.000005        1
# 0.000018        1
# 0.000029        1
# ...

# %%
concat_truth_hits_df = pd.concat([truth,hits], axis=1)

# %%
concat_truth_hits_df.count()
# Out:
# hit_id         120939
# particle_id    120939
# tx             120939
# ty             120939
# tz             120939
# tpx            120939
# tpy            120939
# tpz            120939
# weight         120939
# hit_id         120939
# x              120939
# y              120939
# z              120939
# volume_id      120939
# layer_id       120939
# module_id      120939
# dtype: int64

# %% [markdown]
# # Cells seems to be discrete data so seeing which cells have the highest number of hit id occurence

# %%
cells.hit_id.value_counts().describe()
# Out:
# count    120939.000000
# mean          5.498607
# std           7.431057
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           6.000000
# max          65.000000
# Name: hit_id, dtype: float64

# %%
cells_by_hit_id_counts = cells.hit_id.value_counts().items()

# %%
type(cells_by_hit_id_counts)
# Out:
# zip

# %%
# len(cells_by_hit_id_counts)

# %%
counter = 0
for cell in cells_by_hit_id_counts:
    print(type(cell))
    counter += 1
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ...

# %%
print(counter)
# Out:
# 120939
