# %%
import trackml
import pandas as pd
import matplotlib as plt
import seaborn as sns
import scipy

# %%
from trackml.dataset import load_event

# %%
# %ls
# Out:
# Descriptive Statistics.ipynb  sample_submission.csv*
# Untitled.ipynb                test/
# Untitled1.ipynb               trackml-library/
# detectors.csv                 train_1.zip
# requirements.txt              train_100_events/

# %%
hits, cells, particles, truth =load_event('/Users/donovanadams/Desktop/GitHub/trackml/train_100_events/event000001000')

# %%
hits.head()
# Out:
#    hit_id          x         y       z  volume_id  layer_id  module_id
# 0       1 -64.409897 -7.163700 -1502.5          7         2          1
# 1       2 -55.336102  0.635342 -1502.5          7         2          1
# 2       3 -83.830498 -1.143010 -1502.5          7         2          1
# 3       4 -96.109100 -8.241030 -1502.5          7         2          1
# 4       5 -62.673599 -9.371200 -1502.5          7         2          1

# %%
cells.head()
# Out:
#    hit_id  ch0  ch1     value
# 0       1  209  617  0.013832
# 1       1  210  617  0.079887
# 2       1  209  618  0.211723
# 3       2   68  446  0.334087
# 4       3   58  954  0.034005

# %%
particles.head()
# Out:
#         particle_id        vx        vy        vz         px         py  \
# 0  4503668346847232 -0.009288  0.009861 -0.077879  -0.055269   0.323272
# 1  4503737066323968 -0.009288  0.009861 -0.077879  -0.948125   0.470892
# 2  4503805785800704 -0.009288  0.009861 -0.077879  -0.886484   0.105749
# 3  4503874505277440 -0.009288  0.009861 -0.077879   0.257539  -0.676718
# 4  4503943224754176 -0.009288  0.009861 -0.077879  16.439400 -15.548900
#
#           pz  q  nhits
# 0  -0.203492 -1      8
# 1   2.010060  1     11
# 2   0.683881 -1      0
# 3   0.991616  1     12
# 4 -39.824902  1      3

# %%
truth.head()
# Out:
#    hit_id         particle_id         tx        ty      tz            tpx  \
# 0       1                   0 -64.411598 -7.164120 -1502.5  250710.000000
# 1       2   22525763437723648 -55.338501  0.630805 -1502.5      -0.570605
# 2       3                   0 -83.828003 -1.145580 -1502.5  626295.000000
# 3       4  297237712845406208 -96.122902 -8.230360 -1502.5      -0.225235
# 4       5  418835796137607168 -62.659401 -9.375040 -1502.5      -0.281806
#
#              tpy           tpz    weight
# 0 -149908.000000 -956385.00000  0.000000
# 1       0.028390     -15.49220  0.000010
# 2 -169767.000000 -760877.00000  0.000000
# 3      -0.050968      -3.70232  0.000008
# 4      -0.023487      -6.57318  0.000009

# %%
concat_truth_hits_df = pd.concat([truth,hits], axis=1)

# %%
concat_truth_hits_df
# Out:
#         hit_id         particle_id          tx          ty      tz  \
# 0            1                   0  -64.411598   -7.164120 -1502.5
# 1            2   22525763437723648  -55.338501    0.630805 -1502.5
# 2            3                   0  -83.828003   -1.145580 -1502.5
# 3            4  297237712845406208  -96.122902   -8.230360 -1502.5
# 4            5  418835796137607168  -62.659401   -9.375040 -1502.5
# 5            6  108087696726949888  -57.085602   -8.189710 -1502.5
# 6            7  968286151951515648  -73.860802   -2.575860 -1502.5
# 7            8  954766419537428480  -63.851200  -10.875400 -1502.5
# 8            9  707072769359085568  -97.248901  -10.906700 -1502.5
# 9           10   67554956483231744  -90.276299   -3.243970 -1502.5
# 10          11  274720539342274560  -59.197399   -0.647788 -1502.5
# 11          12                   0  -42.617699  -10.666100 -1502.5
# 12          13   63061596057894912  -72.514603    2.623950 -1502.5
# ...

# %% [markdown]
# # Cells seems to be discrete data soo seeing which cells have the highest number of hit id occurence

# %%
cells.hit_id.value_counts().describe()
# Out:
# count    120939.000000
# mean          5.498607
# std           7.431057
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           6.000000
# max          65.000000
# Name: hit_id, dtype: float64

# %%
cells_by_hit_id_counts = cells.hit_id.value_counts().items()

# %%
type(cells_by_hit_id_counts)
# Out:
# zip

# %%
# len(cells_by_hit_id_counts)

# %%
counter = 0
for cell in cells_by_hit_id_counts:
    print(type(cell))
    counter += 1
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# ...

# %%
print(counter)
# Out:
# 120939
